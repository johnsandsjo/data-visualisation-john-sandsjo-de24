# %% [markdown]
# # Exercise 0.0

# %% [markdown]
# a)
# Do some EDA with info, find out column names, shape of dataset,
# describe method to get summary descriptive statistics.

# %%
import pandas as pd
df = pd.read_csv("../../codealongs/02_matblotlib_barline/data/norway_new_car_sales_by_month.csv")
df
# Out:
#      Year  Month  Quantity  Quantity_YoY  Import  Import_YoY     Used  \
# 0    2007      1     12685          5227    2276         257      NaN
# 1    2007      2      9793          2448    1992         -89      NaN
# 2    2007      3     11264          1445    2626          45      NaN
# 3    2007      4      8854           504    2220        -130      NaN
# 4    2007      5     12007          1592    2881           7      NaN
# ..    ...    ...       ...           ...     ...         ...      ...
# 116  2016      9     13854          1433    1526        -373  42780.0
# 117  2016     10     11932         -1265    1365        -443  39797.0
# 118  2016     11     13194           594    1305        -233  39721.0
# 119  2016     12     13602           524    1137         -96  31761.0
# 120  2017      1     13055          2064    1549         330  36078.0
#
#      Used_YoY  Avg_CO2  Bensin_Co2  Diesel_Co2  Quantity_Diesel  Diesel_Share  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               121 non-null    int64
#  1   Month              121 non-null    int64
#  2   Quantity           121 non-null    int64
#  3   Quantity_YoY       121 non-null    int64
#  4   Import             121 non-null    int64
#  5   Import_YoY         121 non-null    int64
#  6   Used               61 non-null     float64
#  7   Used_YoY           49 non-null     float64
#  8   Avg_CO2            121 non-null    int64
#  9   Bensin_Co2         121 non-null    int64
#  10  Diesel_Co2         121 non-null    int64
#  11  Quantity_Diesel    121 non-null    int64
#  12  Diesel_Share       121 non-null    float64
#  13  Diesel_Share_LY    121 non-null    float64
#  14  Quantity_Hybrid    73 non-null     float64
#  15  Quantity_Electric  73 non-null     float64
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Quantity', 'Quantity_YoY', 'Import', 'Import_YoY',
#        'Used', 'Used_YoY', 'Avg_CO2', 'Bensin_Co2', 'Diesel_Co2',
#        'Quantity_Diesel', 'Diesel_Share', 'Diesel_Share_LY', 'Quantity_Hybrid',
#        'Quantity_Electric', 'Import_Electric'],
#       dtype='object')

# %%
df.shape
# Out:
# (121, 17)

# %%
df.describe()
# Out:
#               Year       Month      Quantity  Quantity_YoY       Import  \
# count   121.000000  121.000000    121.000000    121.000000   121.000000
# mean   2011.545455    6.454545  11134.297521    392.586777  2204.371901
# std       2.915476    3.488075   1752.046397   1789.539953   573.127896
# min    2007.000000    1.000000   5353.000000  -4548.000000  1048.000000
# 25%    2009.000000    3.000000  10250.000000   -526.000000  1812.000000
# 50%    2012.000000    6.000000  11385.000000    493.000000  2263.000000
# 75%    2014.000000    9.000000  12337.000000   1445.000000  2625.000000
# max    2017.000000   12.000000  14207.000000   5227.000000  3768.000000
#
#         Import_YoY          Used     Used_YoY     Avg_CO2  Bensin_Co2  \
# count   121.000000     61.000000    49.000000  121.000000  121.000000
# mean   -135.049587  36864.737705   973.122449  129.520661  133.735537
# std     545.395787   4230.548664  2728.915662   22.719338   17.094233
# ...

# %% [markdown]
# b) Draw a line chart of quantity for each year. Is there a year that should be skipped?

# %%
import duckdb
df_year = duckdb.query(
    """--sql
    SELECT year, SUM(quantity) as Quantity
    FROM df
    GROUP BY year
    ORDER BY year
"""
).df().set_index("Year")
df_year
# Out:
#       Quantity
# Year
# 2007  129195.0
# 2008  110617.0
# 2009   98675.0
# 2010  127754.0
# 2011  138345.0
# 2012  137967.0
# 2013  142151.0
# 2014  144202.0
# 2015  150686.0
# 2016  154603.0
# 2017   13055.0

# %%
#skipping last year as it is not complete
df_year.iloc[:-1].plot()
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# c) Draw a line chart of average CO2 emissions for same years that as in b)

# %%
import duckdb
df_year_co2 = duckdb.query(
    """--sql
    SELECT year, SUM(Avg_CO2) as Avg_CO2
    FROM df
    GROUP BY year
    ORDER BY year
"""
).df().set_index("Year").iloc[:-1]
df_year_co2
# Out:
#       Avg_CO2
# Year
# 2007   1908.0
# 2008   1896.0
# 2009   1811.0
# 2010   1688.0
# 2011   1608.0
# 2012   1559.0
# 2013   1476.0
# 2014   1325.0
# 2015   1197.0
# 2016   1120.0

# %%
ax = df_year_co2.plot()
ax.set(ylabel= "Average CO2 emissions", title="Average emissions by year")
# Out:
# [Text(0, 0.5, 'Average CO2 emissions'),
#  Text(0.5, 1.0, 'Average emissions by year')]

# %%
import duckdb
df_year_month_import = duckdb.query(
    """--sql
    SELECT 
        year || '-' || LPAD(CAST(month as VARCHAR),2,'0') as year_month,
        SUM(import) as tot_import
    FROM df
    GROUP BY year, month
    ORDER BY year, month
"""
).df().set_index("year_month").iloc[:-1]
df_year_month_import
# Out:
#             tot_import
# year_month
# 2007-01         2276.0
# 2007-02         1992.0
# 2007-03         2626.0
# 2007-04         2220.0
# 2007-05         2881.0
# ...                ...
# 2016-08         1485.0
# 2016-09         1526.0
# 2016-10         1365.0
# 2016-11         1305.0
# 2016-12         1137.0
#
# [120 rows x 1 columns]

# %%
df_year_month_import.plot()
# Out:
# <Axes: xlabel='year_month'>

# %% [markdown]
# e) Draw a line chart of all years and months for average CO2 emissions

# %%
import duckdb
df_year_month_co2 = duckdb.query(
    """--sql
    SELECT 
        year || '-' || LPAD(CAST(month as VARCHAR),2,'0') as year_month,
        SUM(Avg_CO2) as co2
    FROM df
    GROUP BY year, month
    ORDER BY year, month
"""
).df().set_index("year_month").iloc[:-1]
df_year_month_co2.plot()
# Out:
# <Axes: xlabel='year_month'>

# %%
import duckdb
df_year_month_e_import = duckdb.query(
    """--sql
    SELECT 
        year || '-' || LPAD(CAST(month as VARCHAR),2,'0') as year_month,
        SUM(Import_Electric) as electric_import
    FROM df
    GROUP BY year, month
    ORDER BY year, month
"""
).df().set_index("year_month").iloc[:-1]
df_year_month_e_import.plot()
# Out:
# <Axes: xlabel='year_month'>

# %% [markdown]
# g) Draw a line chart of average diesel share per year

# %%
import duckdb
df_year_month_diesel_share_avg = duckdb.query(
    """--sql
    SELECT 
        year || '-' || LPAD(CAST(month as VARCHAR),2,'0') as year_month,
        AVG(Diesel_Share) as avg_diesel_share
    FROM df
    GROUP BY year, month
    ORDER BY year, month
"""
).df().set_index("year_month").iloc[:-1]
df_year_month_diesel_share_avg.plot()
# Out:
# <Axes: xlabel='year_month'>

# %%
#turn it into a function
def plot_summary(agg_func, metric, summary_stats):
    df_to_plot = duckdb.query(
        f"""--sql
        SELECT 
            year || '-' || LPAD(CAST(month as VARCHAR),2,'0') as year_month,
            {agg_func}({metric}) as {summary_stats}
        FROM df
        GROUP BY year, month
        ORDER BY year, month
    """
    ).df().set_index("year_month").iloc[:-1]
    df_to_plot.plot()
plot_summary("AVG", "Diesel_Share", "Diesel_average")
plot_summary("SUM", "Import_Electric", "electric_import")
